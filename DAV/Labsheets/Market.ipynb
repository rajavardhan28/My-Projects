# %% [markdown]
# Market Basket analysis is used by companies to identify items that are frequently purchased together.
#
# How Does Market Basket Analysis Work?
#
#
# Market basket analysis if frequently used by restaurents,retailer stores,and online shopping  platforms to encourage customers to make more opurchases in a single visit. This is use-case of data science in marketing that increases company sales and drives business growth and commonly utilizes the Apriori Algorithm.
#
#
#
# **What is the Apriori Algorithm?**
#
# The Apriori algorithm is the most common technique for performing market basket analysis.
#
# It is used for association rulr mining,which is a rule-based process to identify correlations between items purchased by users.

# %% [markdown]
# **What Are The Components Of Apriori Algorithm?**
#
# The Apriori algorithm has three main components:
#
# *Support
#
# *Life
#
# *Confidence
#
# Here is a tabular representation of this purchase data:

# %% [markdown]
# **Milk     Beer    Eggs    Bread    Bananas    Apples**

# %% [markdown]
# Support(item)=Transactions comprising the item/Total transactions
#
#
# A high support value indicates that the item is present in most purchases,therefore markets should focus on it more.
#
# **Confidence**
# It tells us about the likelohood of different purchases combinations. we calculate that using the following formula:
# Confidence(Bread->Milk)= Transactions comprising bread and milk / Transactions comprising bread
# **Lift**
# Finally Lift refers to the increase in the ratio of the sale of milk when you sell bread:
# Lift= Confidence(Bread -> Milk)/Support(Bread)=0.75/1=1.3.
# This Means that customers are 1.3 times more likely to buy milk if u also sell bread.

# %% [markdown]
# **Step 1: Pre-requisites for performing Market Basket Analysis**
#
# Download the dataset "groceries_dataset.csv"
#
#
# **Step 2: Reading the Dataset**

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/Groceries_dataset.csv')
df=df.head()

# %%
df['single_transaction']=df['Member_number'].astype(str)+''+df['Date'].astype(str)

df.head()
# Out:
#    Member_number        Date   itemDescription single_transaction
# 0           1808  21-07-2015    tropical fruit     180821-07-2015
# 1           2552  05-01-2015        whole milk     255205-01-2015
# 2           2300  19-09-2015         pip fruit     230019-09-2015
# 3           1187  12-12-2015  other vegetables     118712-12-2015
# 4           3037  01-02-2015        whole milk     303701-02-2015

# %%
df2=pd.crosstab(df['single_transaction'],df['itemDescription'])
df2.head()
# Out:
# itemDescription     other vegetables  pip fruit  tropical fruit  whole milk
# single_transaction
# 118712-12-2015                     1          0               0           0
# 180821-07-2015                     0          0               1           0
# 230019-09-2015                     0          1               0           0
# 255205-01-2015                     0          0               0           1
# 303701-02-2015                     0          0               0           1

# %%
def encode(item_freq):
  res=0
  if item_freq > 0:
    return res

basket_input=df2.applymap(encode)

# %% [markdown]
# **step 4: build the apriori algorithm for market basket analysis**
#
# now, let's import the apriori algorithm from the MLXtend python package and use it to discover frequently-bought together item combinations

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
frequent_itemsets = apriori(basket_input, min_support=0.001, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
